# %% [markdown]
# ## Data Cleaning
# - Outliers
#     - Outlier removal based on z-score. The z-score is calculated on the user input variable and values with absolute z-score greater than threshold_z for the user input granularity.
# - Standardization
#     - Standardization of SKU/Store names and finding top three matches based on fuzzy score.
#     - User inputs two lists of strings. First list will be reference list and top three matches will be found from second list.
#     - Takes 16 min on model dataset with 800 x 800 combinations.
# - Output file location: Output/Data_Cleaning

# %%
import numpy as np
import pandas as pd
import datetime
import time
pd.options.mode.chained_assignment = None
import re
import jellyfish as jf
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from joblib import Parallel, delayed

# %%
#!pip3 install fuzzywuzzy

# %% [markdown]
# - Outliers function

# %%
def outliers(df,
             variable, # column on which to find z-score e.g Sales column
             year_col,
             period_level,
             gran_list, # list of granularity e.g. ['Segment','Brand','APN']
             threshold_z = 1.96): 
    
    """
    Function to remove outliers using z-score from the dataset. The user can input the variable on which to perform z-score.
    The values with absolute z-score >= 1.96 are removed.
    
        Parameters in order:
            df: Dataframe
            variable: The column on which to perform z-score e.g. Unit sales column
            year_col: Year column
            period_level: The aggregating column used for calculation of mean and standard deviation for the input 'variable'.
                          Can be Month column, Quarter column, etc.
            gran_list (list): List of granularity column across which calculation is to be done. e.g. ['Segment','Brand','SKU']
                                for Segment x Brand x SKU
            threshold_z (float): Threshold z-score value. Default= 1.96
        Returns:
            The original dataframe with outliers removed
    """
    gran_list.extend([year_col,period_level])
    df['Std'] = df.groupby(gran_list)[variable].transform('std') # finding standard deviation
    df['Mean'] = df.groupby(gran_list)[variable].transform('mean') # finding mean
    
    # calculating z-score for entries
    df['z-score'] = abs(df[variable]-df['Mean'])/df['Std']
    
    # filtering data with z-score > threshold_z
    df = df[df['z-score'] < threshold_z]
    
    df = df.reset_index(drop=True)
    
    df.drop(columns=['Std','Mean','z-score'],axis=1,inplace=True)
    
    df.to_csv('../Output/Data_Cleaning/Outliers_removed.csv',index=False)
    
    return df

# %% [markdown]
# - Standardization function

# %%
# Dependencies for main functions
# function to covert to utf-8 string
def to_unicode(obj, encoding='utf-8'):
    if not isinstance(obj, str):
        return obj.decode(encoding, errors='ignore')
    return obj


def f_get_modified_str(input_str):
    # Transform to lower case
    input_str = input_str.strip().lower()
    # Replace '&' char to word 'and'
    input_str = input_str.replace(' & ', ' and ')
    input_str = input_str.replace('&', '')
    # Remove all other special chars excluding '.'
    input_str = " ".join(re.findall("[a-zA-Z0-9.]+", input_str))
    # Remove extra spaces
    input_str = " ".join(input_str.split()) # split saves words of string as list
    return input_str.strip()

#name1(Tesco) = Mars
#name2 (Efun)= Mars
#score 100

#name1 = Mars
#name2 = Galaxy
#score 5

def name_match(name1, name2):
    ratio1=0.0
    ratio2=0.0
    name1 = name1.split()
    name2 = name2.split()
    if name1 and name2:
        ratio1 = 0.0
        for i in range(len(name1)):
            for j in range(i, len(name2)):
                if fuzz.ratio(name1[i], name2[j]) > 90:
                    ratio1 += 1.0
                    break
        try:
            ratio1 = 100 * (ratio1 / len(name1))
        except ZeroDivisionError:
            ratio1 = 0.0
        ratio2 = 0.0
        for i in range(len(name2)):
            for j in range(i, len(name1)):
                if fuzz.ratio(name2[i], name1[j]) > 90:
                    ratio2 += 1.0
                    break
        try:
            ratio2 = 100 * (ratio2 / len(name2))
        except ZeroDivisionError:
            ratio2 = 0.0
    return int(max(ratio1, ratio2))


# Function to calculate fuzzy match score for two given strings

def f_name_match_score(str1, str2):
    """
    Main function to modify the strings and calculate fuzzy scores.
    
    Returns score of two strings.
    """
    # Convert to unicode to avoid error
    
    str1 = to_unicode(str1)
    str2 = to_unicode(str2)
    # Transform name
    str1 = f_get_modified_str(str1)
    str2 = f_get_modified_str(str2)
    # Compute match scores
    score1 = fuzz.ratio(str1, str2)
    score2 = fuzz.token_sort_ratio(str1, str2)
    score3 = jf.jaro_winkler(str1, str2) * 100
    score4 = fuzz.WRatio(str1,str2)
    score6 = name_match(str1,str2)
    score5 = 0
    if ((len(str2.split()) >= 1) & (len(str1.split()) >= 1)):
        score5 = fuzz.ratio(str1.split()[0], str2.split()[0])
    if (score5>0):
        s_max = (score1 + score2 +score3 + score4 + score5 + score6)/6
    else:
        s_max = (score1 + score2 +score3 + score4 + score6)/5

    return s_max

# Main function
def sku_standardize(str_list_1, str_list_2):
    """
    Function to output string list and its top 3 matches for each string from another string list based on 
    fuzzy score calculation.
    
        Parameters in order:
            str_list_1(list)(str) : String list 1
            str_list_2(list)(str) : String list from which to get best matches
            
        Returns:
            Dataframe with strings, their top 3 matches and score out of 100
            
    """
    index = pd.MultiIndex.from_product([str_list_1, str_list_2], names = ["Name", "Options"])
    index = pd.DataFrame(index = index).reset_index()
    scores = []
    for i in str_list_1:
        element_run = Parallel(n_jobs=4)(delayed(f_name_match_score)(i,j) for j in str_list_2)
        scores.extend(element_run)
    index['Score'] = scores
    df_agg = index.groupby(['Name','Options']).agg({'Score':sum})
    df_agg = df_agg['Score'].groupby('Name', group_keys=False).nlargest(3).reset_index()
    df_agg['Rank'] = list(np.arange(1,4))*len(str_list_1)
    
    df_agg.to_excel('../Output/Data_Cleaning/Standardization-Top_matches.xlsx',index=False)
    
    return df_agg

# %% [markdown]
# ### Validation on Model dataset

# %% [markdown]
# - Outliers

# %%
df = pd.read_excel('../Data/Testing_Data.xlsx')

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df.head()
# Out:
#     Segment       Date Retailer  Manufacturer            APN Packsize  \
# 0  Bitesize 2017-04-02    Coles  Mars Wrigley  5000159491532      88g
# 1  Bitesize 2017-04-02    Coles  Mars Wrigley  5000159494762     149g
# 2  Bitesize 2017-04-02    Coles  Mars Wrigley  9300682002134     140g
# 3  Bitesize 2017-04-02    Coles  Mars Wrigley  9300682013376     145g
# 4  Bitesize 2017-04-02    Coles  Mars Wrigley  9300682015479     145g
#
#        Brand       Sales  Unit_sales  Vol_Sales  wtd_distribution  \
# 0     Galaxy    9201.320      2570.0    226.160              75.9
# 1      M&M's      61.760        61.0      9.089               1.9
# 2  Maltesers  178508.416     61625.0   8627.500              99.9
# 3      M&M's   87435.360     30179.0   4375.955             100.0
# 4      M&M's   30701.950     10589.0   1535.405              95.9
#
#           PPG_Item_No  Year  Month
# 0  Item_5000159491532  2017      4
# 1  Item_5000159494762  2017      4
# 2  Item_9300682002134  2017      4
# 3  Item_9300682013376  2017      4
# 4  Item_9300682015479  2017      4

# %%
ds = outliers(df,'Unit_sales','Year','Month',['Segment','Retailer','Manufacturer','Brand'])

# %%
ds
# Out:
#         Segment       Date    Retailer            Manufacturer            APN  \
# 0      Bitesize 2017-04-02       Coles            Mars Wrigley  5000159491532
# 1      Bitesize 2017-04-02       Coles            Mars Wrigley  5000159494762
# 2      Bitesize 2017-04-02       Coles            Mars Wrigley  9300682015479
# 3      Bitesize 2017-04-02       Coles            Mars Wrigley  9300682026079
# 4      Bitesize 2017-04-02       Coles            Mars Wrigley  9300682030892
# ...         ...        ...         ...                     ...            ...
# 91676     Block 2020-03-22  Woolworths  All Other Manufacturer  9403142002375
# 91677     Block 2020-03-22  Woolworths  All Other Manufacturer  9403142004652
# 91678     Block 2020-03-22  Woolworths  All Other Manufacturer  9403142004836
# 91679     Block 2020-03-22  Woolworths        Lindt & Sprungli     9542009984
# 91680     Block 2020-03-22  Woolworths        Lindt & Sprungli     9542045371
#
#       Packsize             Brand      Sales  Unit_sales  Vol_Sales  \
# 0          88g            Galaxy   9201.320      2570.0    226.160
# 1         149g             M&M's     61.760        61.0      9.089
# 2         145g             M&M's  30701.950     10589.0   1535.405
# 3         145g             M&M's  39682.610     13699.0   1986.355
# 4         180g              Pods    483.550       160.0     28.800
# ...        ...               ...        ...         ...        ...
# 91676     200g        Whittakers      4.796         1.0      0.200
# 91677     100g        Whittakers   2186.008       489.0     48.900
# 91678     100g        Whittakers   2678.324       600.0     60.000
# 91679     100g  Lindt Excellence  39306.531     11410.0   1141.000
# 91680      80g  Lindt Excellence  35486.671     10208.0    816.640
#
#        wtd_distribution         PPG_Item_No  Year  Month
# 0                  75.9  Item_5000159491532  2017      4
# 1                   1.9  Item_5000159494762  2017      4
# 2                  95.9  Item_9300682015479  2017      4
# 3                  95.8  Item_9300682026079  2017      4
# 4                  14.6  Item_9300682030892  2017      4
# ...                 ...                 ...   ...    ...
# 91676               0.2  Item_9403142002375  2020      3
# 91677              26.9  Item_9403142004652  2020      3
# 91678              27.8  Item_9403142004836  2020      3
# 91679             100.0     Item_9542009984  2020      3
# 91680              99.6     Item_9542045371  2020      3
#
# [91681 rows x 14 columns]

# %% [markdown]
# - Standardization

# %%
df2 = pd.read_excel('../Data/SKU-standardisation.xlsx','Sheet2')

# %%
list1 = list(df2['A'])
list2 = list(df2['B'])
list1 = [x for x in list1 if str(x) != 'nan']
list2 = [x for x in list2 if str(x) != 'nan']

# %%
df_ag = sku_standardize(list1,list2)

# %%
df3 = pd.read_excel('../Data/SKU-standardisation.xlsx','Sheet1')

# %%
list1 = list(df3['Product Name'])
list2 = list(df3['Description_english'])
list1 = [x for x in list1 if str(x) != 'nan']
list2 = [x for x in list2 if str(x) != 'nan']

# %%
s = time.time()
df_ag2 = sku_standardize(list1,list2)
e = time.time()

# %%
print(e-s)
# Out:
# 1044.752935886383

# %%
df3 = pd.read_excel('../Data/SKU-standardisation.xlsx','Sheet3')
list1 = list(df3['Activity Name'])
list2 = list(df3['Short Text'])
list1 = [x for x in list1 if str(x) != 'nan']
list2 = [x for x in list2 if str(x) != 'nan']

# %%
list1
# Out:
# ['Spring Multibrand',
#  'Easter',
#  'Back-2-School Multibrand',
#  'New Year Multibrand',
#  'Snickers EBA + LE Cream',
#  'Big Bar promo',
#  'Snickers Crisper',
#  'Twix White',
#  'Twix Hot Beverages EBA',
#  'Snickers Stick',
#  'Snickers Hunger Bar EBA',
#  'Twix Salted Caramel',
#  'Snickers White LE',
#  'Orbit Dating',
#  'Orbit Car Occasion',
#  'Orbit Multibrand',
#  'Orbit Mega',
#  'Orbit Car Occasion 2.0',
#  'Orbit Dating 2.0',
#  "Korkunov Teacher's Day",
#  'Dacha Multibrand',
#  'Five EBA 5 Adventures',
#  'Five AGM',
#  'Five Gaming EBA',
#  'M&Ms You&Me',
#  'Skittles Spider Man',
#  'M&Ms Tablet',
#  'M&Ms Screentime 1.0',
#  'Bitesize Screentime 2.0']

# %%
list2
# Out:
# ['Orbit D-Com Plan Digital',
#  'Easter 2020 national KV + recipes',
#  "RU_M&M's_Screentime EBA_0420-Plan-",
#  '6470200,00 - Buzova',
#  'BE-KIND Rosa Ski resort activation 2',
#  'Orbit White Mega campaign',
#  "16_CE_M&M's Customization for retail (Ma",
#  'Premia_Go-pro_SNK EBA P3-4 2020',
#  'Premia_JBL_SNK EBA P3-4 2020',
#  'Premia_Camera_SNK EBA P3-4 2020',
#  'Premia_Playstation_SNK EBA P3-4 2020',
#  'Premia_Iwatch_SNK EBA P3-4 2020',
#  "RU_M&M's_Screentime EBA Social Support_0",
#  'Five - KV for Soft Chew',
#  'Skittles Ex-Football 2020_TMA Execution',
#  'Five_Shmot_LoL Licence',
#  'MMs_ivi_Content Rolls campaign_20200211',
#  'Dove Caramel NY LE',
#  'BE-KIND nutrition design',
#  'Five Gaming fonts purchase',
#  '27_CE_MMs_Statis banner for Okey',
#  'BE-KIND act of kindess Perito',
#  'BE-KIND METRO Expo 2020',
#  '361.604,80 - MEGA (OOH Universities)',
#  'Five gaming streamers',
#  'SNK & Orbit KV development',
#  '05_SNK NY Tube Design Development',
#  'TMA Presentation design',
#  'SNK EBA 2020 banner production',
#  'Five - video production for Effie',
#  "18_CE_M&M's_Branding for YT channel deve",
#  'BE-KIND SMM 2020',
#  'Orbit Mega Launch kontakt decoration',
#  'Joint Bitesize Footbal EBA cust for SKTL',
#  'Orbit+SNK designs for X5 customization',
#  '15_CE_MMs_Football_actors_buyouts_prolon',
#  'BE-KIND POSM stickers (Perek)',
#  '13_CE_MMs_Images for big parcel pack buy',
#  'Consumer promo_Nikolayevskiy_2',
#  'BE-KIND University activation/ sampling',
#  'BE-KIND ambassadors sampling MSK/SPB',
#  'Orbit BPI Dating 1.0_Effie_BBDO',
#  'SNK Stick KV development',
#  'BE-KIND paid media Q1',
#  'Edadeal bite size Feb-March 2020',
#  'BTL_ SNK HB EBA 2020_2d part',
#  'Juicy Fruit - reformats of creatives',
#  'SNKCrisper stock after BTLdelivery2019',
#  'Orbit BPI VideoCV Mediaplan',
#  'Orbit sampling Lovetech',
#  'BBDO_KV_Five_30187,2',
#  'BE-KIND Anti-Bullying activation',
#  'Consumer promo_Nikolayevskiy_3',
#  'Boxes for MMs Screentime sale kit 2020',
#  'Stickers for mock-ups Twix Orange',
#  'Consumer promo_Nikolayevskiy_1',
#  'BE-KIND D-com support H1 2020',
#  "RU_M&M's_D-com_0420_Plan-Digital",
#  "22_CE_M&M's football prepack for Magnit",
#  '19_M&Ms_Cupboard adaptation_packshot_upd',
#  'MMs Screentime kit for sales 2020',
#  'BE-KIND sampling Sochi',
#  'BE-KIND Rosa Fest Activation',
#  '20_Twix_Ginger_packaging re-design',
#  'Orbit BPI Video CV Blogers Mediacom',
#  'Premium BiteSize design update',
#  "TMA_MM's_ролик_26092019",
#  '12_Twix_HOT BEVERAGE AMPL Agency cost',
#  "13_CE_M&M's Customization for retail (Ma",
#  "Orbit Mega digital support BBDO P11'19",
#  'Perek online banners visuals',
#  'SNK First Visitors voice-over',
#  'Orbit XXL media support',
#  'RU_M&Ms_D-comm Support_0420_Digital-Plan',
#  'Twix Salted Caramel_Edadeal',
#  'Five - development of KV for LE POSM',
#  'New Year 2020 portfolio Edadeal (NCP)',
#  'Dove Caramel Image rights',
#  'PO SNK NB+BBP_KV adoptation for POSM',
#  'Korkunov_RightsPhotoWomen_Spring2021',
#  'Snickers Social posts for VK',
#  'Five-shmot-Ozon placement',
#  'Orbit Beeline summer sampling',
#  'Beeline sampling PO extension',
#  'Five packshots 3Ds',
#  '34_Images buyouts for NY egg',
#  'B2S 2020 Edadeal cash-back',
#  'SNICKERS COVID creatives-global adaptati',
#  'Skittles Venom 2020_TMA execution',
#  'Twix_ and_Seasons_Dcom_Support',
#  'MP5 Lenta listing samples TMA',
#  'Twix & SNK Multipack 3d update',
#  'Orbit d-com banners(under mask) BBDO',
#  'Travel pillow',
#  'Sport bag',
#  'Backpack',
#  'Belt bag',
#  'Hoodie',
#  'Shopper bag',
#  'Longboard',
#  'snickers.ru Dataline Hosting Q1-Q4_2020',
#  'HeadphoneSNK EBA P3-4 20_2nd part_Suprem',
#  'Bike SNK EBA P3-4 20_Supremia',
#  'Ball SNK EBA P3-4 20_Supremia',
#  'BE-KIND small POSM production',
#  "TMA_MM's_Screentime_Event",
#  "TMA_MM's_Screentime_Event2004",
#  'Snickers Plombir cases design developmen',
#  'Twix Orange_cases_design development',
#  'Media support Twix_Hot Beverage_Platform',
#  'ProductPhotoshoot_Restage_Korkunov',
#  'SNK OTH // D-comm photo',
#  'SNK Crisper // D-comm OLV',
#  'Orbit Stickers design',
#  'SNK Almond // Pack deisgn',
#  'Personal care brand - Outdoor',
#  'KKV Restage Sberbank Cashback',
#  '5Gum.ru Dataline Hosting Q1-Q4_2020',
#  'Consumer promo_Remi_6/04-10/05_1 part',
#  'NY Portfolio photoshoot',
#  'Orbit D com banners for sampling',
#  'Personal Care Tik Tok - 10999997',
#  'Additional entry to PO #1002631061',
#  'Consumer promo_Remi_6/04-10/05_3 part',
#  'Consumer promo_Remi_6/04-10/05_6 part',
#  'MMs cretive delievry',
#  'Spring2021_KV_Korkunov_BBDO',
#  'Consumer promo_Remi_6/04-10/05_4 part',
#  '4510871432_Промо в дком. Сертификаты.вес',
#  "53_CE_MM's_Images buyouts for NY watch",
#  'Choco_Fee_with projects_Stages 1504',
#  'Five gaming D-com',
#  "M&M's_Screentime EBA 2.0 Digital plan",
#  "M&M's D-com catalogues",
#  "SNK EBA'21 // Creative idea translation",
#  '48_CE_MMs_Bitesize hoodie',
#  '4510869573_Отключение цен в разделах на',
#  'BE-KIND nutrition presentation update',
#  'Korkunov_VoiceActingTDNY_AgencyFee',
#  'Korkunov_VoiceActing_TD_NY',
#  'Skittles Ozon KV 2020',
#  'Consumer promo_Remi_6/04-10/05_2 part',
#  'Orbit D-com materials add cost BBDO',
#  '4510869932_внеплановое обновление сайта',
#  '20_CE_M&Ms_Screentime sponsoship adaptat',
#  '21_CE_MMs_Bitesize hoodies printing',
#  'SMM_Korkunov_June_Digitas',
#  'BTL_Twix Salted caramel_inner event 2020',
#  '4510869574_Заполнение контента на сайте',
#  'MMinis Celebrations',
#  "50_CE_MM's_Multiroll VO for YL",
#  'Web Analytics_26121211',
#  'Web Analytics_26121111',
#  'Web Analytics_26121151',
#  'Web Analytics_26121671',
#  'Web Analytics_26121681',
#  'Web Analytics_26121621',
#  'Web Analytics_26121631',
#  'D-comm strategy 2k21_26121211',
#  'D-comm strategy 2k21_26121111',
#  'D-comm strategy 2k21_26121151',
#  'D-comm strategy 2k21_26121671',
#  'D-comm strategy 2k21_26121681',
#  'D-comm strategy 2k21_26121621',
#  'D-comm strategy 2k21_26121631',
#  'Korkunov_retouch_Spring2021',
#  '"4510867746_Медийная кампания ""туристы"',
#  '4510868414_Поддержка сезонов в клиенте О',
#  '4510866595_медиаподдержка промопостов дл',
#  '4510868300_Диджитал полки для Перекрестк',
#  'SNK pre-pack design for Lenta',
#  'SMM_Korkunov_July_Digitas',
#  '55_Magnit_animated banner',
#  '4510871433_Разработка баннеров для еком.',
#  "MM's_Screentime stories for Ozon",
#  'M&M_Медиасервисы_анонс_лавка_200520',
#  'Add to PO 2009985836',
#  'D-com assets BBDO 5 gaming',
#  'Orbit VK stickers',
#  "RU_M&M's_Football Customization_0620",
#  '4510869388_Сверхурочные для запуска сайт',
#  "M&M's_Screentime assets update",
#  '4510871343_Продакшн баннера на коркунов',
#  '4510871623_Разработка креатива кнопки на',
#  '4510871826_Создание и поддержка SMM март',
#  '4510872104_Фотосьемка Новый год 2020',
#  '4510872602_дизайн вкладыша 192 #Новый вк',
#  'Korkunov_ICP2021_BBDO',
#  'Twix for sales Video 15052020',
#  'SNK Effie // 09 Crisper case production',
#  '4510867658_мотивационная программа для s',
#  'Five D-com MP',
#  'BE-KIND POSM for Globus & BP',
#  'Internal PR - digital game',
#  'Orbit BPI Tander customization',
#  'Milky Way - Showbox for Super Bar (1+1 )',
#  'SNK stickers for Tuba buy-out',
#  'Orbit 2020 EBA Mega, Car, Dating P3-P8',
#  '257.300.00 - Music for Tik Tok',
#  'VK App Convergent without modules',
#  '34_CE_MMs_Images for Stay Home activatio',
#  '4510869795_Фотосъемка портфеля для весны',
#  '4510871345_Разработка уникального скю дл',
#  '4510871629_Разработка и ведение соц сете',
#  'GUM_banners for WB_ BBDO',
#  'SNK Effie // 08 Students & HB 2019',
#  'BE-KIND nutrition presentation develop',
#  "43_CE_M&M's_Football customization with",
#  "49_CE_MM's_Dcom support with Yandex",
#  'Milky Way Strawberry Showbox update',
#  '4510870063_Создание контента для соцсете',
#  '4510872600_Назначение выкуп изображений',
#  "51_CE_MM's_Dcom with YL Production",
#  'SNK Effie // 10 Voice-over all cases',
#  'Perekrestok Online Spring Consumer promo',
#  'SNK Effie // 11 application cost',
#  "Yandex_Lavka_Specials_M&M's 14.05",
#  'Five gaming Digital Plan FTE',
#  'Orbit 14 february_mediaplacement',
#  "45_CE_M&M's_Game images buyouts",
#  'SNK OTHER // Mini pre-pack displays dsgn',
#  'BE-KIND Sochi sampling Q2',
#  'orbit-promo.ru Dataline HostingQ1-Q42020',
#  '4510871394_Участие в наминации Digital E',
#  'Five Measurements',
#  'Easter 2020 web-site',
#  'Competetive monitoring for Mars',
#  'BE-KIND SMM influencers Winter-Spring',
#  'Twix_Factory tour_buttons',
#  '4510871473_Весенняя SEO кампания',
#  '4510871872_Разработка креатива 2х скю на',
#  '4510871873_Разработка креатива 2х скю на',
#  '4510872378_Publicis Group',
#  '4510872561_Продолжение работы над проект',
#  'Five_gaming_trays_images',
#  '4510866576_проведение весенней медийной',
#  '4510868094_Online reputation management',
#  "RU-MM's_Easter_0420-Plan-Digital_2019012",
#  "TMA_MM's_M&M's Storage&Logistics20",
#  'Five_Shmot_MP_Mediacom',
#  "41_CE_MM's_Digital video adaptation for",
#  '4510868651_Новогодняя кампания 2019-2020',
#  '4510870064_Создание контента для соцсете',
#  '4510870907_Боллпарк НГ копии',
#  'Perek Bounty Pineapple catalogue',
#  '30_CE_MMs_Statis banners for Okey - cate',
#  '4510872103_Новый год 2020',
#  '4510865751_разработка дизайнов на день у',
#  '4510866299_весенняя медиакампания 2019',
#  '4510867136_Подготовка имиджей портфеля д',
#  '4510868029_Подготовка материалов для кам',
#  '4510872614_выкуп изображения для паллеты',
#  'Twix SC_landing page 2020',
#  'Snickers_EBA on-the-go_Plan-Digital',
#  '201.525,19 - Car Occasion (OOH)',
#  'TV SP_MMs_STS_april20_to_sent 2303_to se',
#  "31_CE_M&M's image for Magnit catalog",
#  'BE-KIND banners for d-com & other Q1',
#  'Aff gum designs',
#  'Five - buyout of photo for KV of LE',
#  '1627232.50 - Car occasion (Radio)',
#  'Five - buyout of music for Effie video',
#  'BE-KIND d-com banners',
#  'GfK Marketing Mix Evaluator',
#  'BE-KIND sampling booking fee Q2(indirec)',
#  '4510872256_Participation in the National',
#  '28_CE_M&Ms_Easter_campaign_extra_cost_fo',
#  'SNK ON HE GO AT HOME - Banners for Dcom',
#  '4510871443_Разработка уникального дизайн',
#  '4510871823_Поддержка Дком клиентов на 20',
#  'SNK_MARS Event Migel participation',
#  'Orbit Dating 2.0 VK mini app CE',
#  'BE-KIND hyatt brochures',
#  "TMA_M&M's_ Lays0303",
#  'Mars_SNK_VK Chat-bot_media plan',
#  'Five Gaming LoL SP',
#  'BE-KIND ambassadors sampling Q2-Q3 2020',
#  'SNK White // tag adaptation',
#  'KV cross-promo SNK_2020_TMA',
#  'KKV Internal Launch mailing design',
#  'Refreshers OLV',
#  'Orbit Refreshers selling kit',
#  'CE_BBDO_Snickers NY_8_digital',
#  'CE_BBDO_Snickers NY_add_agency_cost',
#  'Five NGM C1_Streamers_WS',
#  'FIVE Gaming EBA’21',
#  'ORBIT EBA’21',
#  'BE-KIND POSM for Gazpromneft',
#  'Content Marketing Training Workshop',
#  'Orbit Dating 2.0 Feduk fee',
#  '38_SNK_Design development_Box Taxi',
#  '39_SNK_Hungerithm 2.0_digital video prod',
#  'Dove Spring LE colorproof',
#  'SNK NY 2020_Edadeal cash-back',
#  '36_SNK_Hungerithm 2020_Digital_adopt',
#  'BE-KIND D-com banners July',
#  'B2S 2020 national creative + Ozon',
#  'Korkunov_SMM_August_Digitas',
#  'Additional cost_Twix Hot Bev TVC',
#  'CE TWIX HotBev UR for 2020 (music)',
#  'Orbit MP5 Lenta_listing samples_Unite',
#  'SNK Mediaplan Hungerithm 2020',
#  '360 Digital Dashboard in Google DS',
#  'BE-KIND bar stickers for sampling',
#  'Halloween image buyout',
#  'Five Dcom Q3',
#  'Skittles Dcom update',
#  'D-Comm_Q3_KKVSupport',
#  'Mock-Ups_Taina_MTVideo_Korkunov',
#  'CE TWIX HotBev UR for 2020 (actors)',
#  'NY 2020 customized BTL in Lenta',
#  "D-Com Perekrestok M&M's IVI 2020",
#  'Five Icecream photoshoot for Dcom',
#  'TWIX salted caramel digital plan',
#  'BTL Twix SC Edadeal for Tander 2020',
#  'add to PO 2010026895_add-l for Twix SC',
#  'Screentime 2.0 Voiceover',
#  'Orbit Dating univercities poster design',
#  'SKN+Orbit // Calcellation fee celebrity',
#  'Boxprototype_Korkunov_Vending',
#  'Twix_HOT BEVERAGE 2020 AMPL Agency cost',
#  'Korkunov_PhotoBuyout_NY20-21',
#  'Orbit Edadeal Perekrestok',
#  'Competitive Monitoring',
#  'Obit Mega d-com banners',
#  '75.272,20 - Styling up_HTC_materials',
#  'BE-KIND cashback flight 1',
#  'Twix Orange design update',
#  "M&M's D-com June-Sept",
#  'KV for Perekrestok',
#  "35_CE_MM's Game for Magnit production on",
#  "39_CE_MM's Game for Magnit production on",
#  '54_ Digital game statistics integration',
#  'SNK P11 TVC // Ivleeva rights buy-out',
#  'Orbit EBA REcovery_pack design_BBDO',
#  'Twix_ and_Choco_Impulse_Dcom_Support',
#  "MM's Tander Pack Support",
#  'TWIX HOT BEVERAGE KEY VISUAL & DISPLAY',
#  'Multipack Stock-up Design Update',
#  'BE-KIND d-com banners creative June',
#  'Skittles D-com banners',
#  'BE-KIND presentation development',
#  'SNK First Visitors TVC voice-over',
#  'CE_MM_NY20-21 Screentime3.0 OLV',
#  'QR code system_OKF',
#  'Twix Multipack Support Creative Cost',
#  'Five NGM C1_Moderation_GG',
#  'KKV_BBDO_NY digital Sber update_84 499,4',
#  'Orbit Cashback Edadeal for X5 Dec 2020',
#  'Orbit EBA Reboost P3-P4 2021',
#  '64_SNK_NY_Galich_OOH',
#  'Five vkbanners for BrandLink support',
#  'VK targeting Community_OKF',
#  'Skittles Football - creative idea',
#  'ORBIT OLV End Line Adaptation',
#  'Five Edadeal NY LE support December 2020',
#  'Korkunov_SMMJuly_Digitas',
#  'Orbit Dating 2020 bloggers',
#  'KKV_BBDO_Spring Copy adapt_855 385,60',
#  'Easter 21_national KV and recipes',
#  'Orbit Refreshers music production',
#  'Orbit Refreshers OLV penalty',
#  'Five Q4 2020 Media_Twitch & MyTarget',
#  'Web Analytics_OKF',
#  'RU_Twix_D-Comm_December',
#  '51_SNK_Loose_KV_design_development',
#  'Five NGM C1 OLV_ballpark',
#  'Five NGM C1 OLV_addition to PO2010324303',
#  'Five OLV Shmot usage rights renewal',
#  'SNK EBA P9-10 2021_1st part in 2020',
#  'BE-KIND ambassadors unifrom prod Q4',
#  'Five NGM C1_boxes',
#  'Twix 3 ingredients Production Cost',
#  'Social Listening_OKF',
#  'Korkunov_Dcommbanners_TD&NY',
#  'KKV_BBDO_copy legal change_13000',
#  'Orbit Refrehsers media materials',
#  'Twix Multipack Support Production Cost',
#  'NY recipe',
#  'MMs_ivi_Content Rolls campaign_2020_upd',
#  'Five OLV Shmot adaptation',
#  'Twix EBA P5-6 2021_1st part in 2020',
#  'Five Eba NGM P1-P2 2021',
#  'KKV_BBDO_NY video prod_33 800',
#  'KKV_BBDO_idea NY21 FEE_1 345 899',
#  'MMs Mediacom TNT TV Sponsorship Jan-Mar',
#  'Five NGM C1_Media Support',
#  'Orbit D-com plan',
#  'Snickers EBA P3-4 2021_1st part in 2020',
#  'SNK_NY_OOH_December',
#  'Orbit Refrehsers Reg toolkit',
#  'KKV Komus Certificates',
#  'SNK EBA 30Y // Web-site design',
#  'SNK 30Y EBA // creative idea 2nd wave',
#  'Orbit Refreshers KV Production',
#  'RU_MM`s_NY_Screentime3.0_PlanDigital_add',
#  'KKV_BBDO_Spring digital displ_268 098,80',
#  'Orbit Refreshers website production',
#  'VK targeting Community_26121211',
#  'VK targeting Community_26121111',
#  'VK targeting Community_26121151',
#  'VK targeting Community_26121671',
#  'VK targeting Community_26121681',
#  'VK targeting Community_26121621',
#  'VK targeting Community_26121631',
#  'Five NGM C1 Widget',
#  'Tander support voiceover',
#  'KKV_Convergent_VK app_300 000',
#  'VK community_26121211',
#  'VK community_26121111',
#  'VK community_26121151',
#  'VK community_26121671',
#  'VK community_26121681',
#  'VK community_26121621',
#  'VK community_26121631',
#  '3998065,97 - GUM Q4',
#  'QR Code System_26121211',
#  'QR Code System_26121111',
#  'QR Code System_26121151',
#  'QR Code System_26121671',
#  'QR Code System_26121681',
#  'QR Code System_26121621',
#  'QR Code System_26121631',
#  'Five_BrandLink support',
#  'Orbit Refreshers digital cards dev',
#  'Orbit Refeshers campaign development',
#  'SNK NY 20_Edadeal prolongation (Dec)',
#  'NY app development_OKF',
#  'KKV_Mediacom_Digital NY-2part_10 893 500',
#  'Orbit YT brand lift',
#  'Social listening_26121211',
#  'Social listening_26121111',
#  'Social listening_26121151',
#  'Social listening_26121671',
#  'Social listening_26121681',
#  'Social listening_26121621',
#  'Social listening_26121631',
#  'Digital Strategy_26121211',
#  'Digital Strategy_26121111',
#  'Digital Strategy_26121151',
#  'Digital Strategy_26121671',
#  'Digital Strategy_26121681',
#  'Digital Strategy_26121631',
#  'SNK NY 2020 national promo_TMA',
#  'ORBIT REFRESHERS Regional EBA’21',
#  'Orbit Mask banner adaptation',
#  'BBDO_Korkunov_NY GZK Sber_43 470',
#  'NY App development_26121111',
#  'NY App development_26121211',
#  'NY App development_26121151',
#  'NY App development_26121671',
#  'NY App development_26121681',
#  'NY App development_26121631',
#  'Twix_Salted Caramel_banners production',
#  'KKV_BBDO_NY 6sec video_213 765,6',
#  'SNK cash-back Brandlink 2d_oct-nov2020',
#  'Orbit_Refreshers_illustration',
#  'Orbit XXL banners',
#  'Five YT placement Nov-Dec',
#  "Orbit d-com amplification Q3'2020",
#  'Five NGM C1_Streamers_GG',
#  'Digital Strategy_OKF',
#  "Skittles Spiderman - packs' designs",
#  "D-Comm M&M's Media",
#  "MM's Screen time creative adaptation",
#  '5Gum.ru Dataline Hosting 2020 Promo',
#  'BE-KIND creatives development for SMM',
#  'AR game development',
#  "M&M's TMA-IVI взаимозачет НГ 2020",
#  'RU_Mars seasons_D-com_1020',
#  'Five Global assets adaptation',
#  'Five OLV_Now you rule_usage rights',
#  'KKV_BBDO_6 sec NY_36 400',
#  'SNK EBA // Ballpark TVC production',
#  'BE-KIND globus display booking fee',
#  'KKV_Konvergent_App design_180 097,5',
#  'Five Gaming backgrounds',
#  'Korkunov_SMM_December',
#  'RU_Mars_Choco_D-com_1020',
#  'KKV_BBDO_Ice cream TV copy_10 000 000',
#  'Размещение навесок Орбит для Ленты',
#  'Five OLV Now you rule_adaptation',
#  'Korkunov_SpringIdea_D-Comm',
#  'Five NGM C1_images buyout',
#  'Find Your Other Half KV Localisati',
#  "MM's EBAs assets adaptation",
#  'BE-KIND ambassadors equipment (pillows)',
#  'Snickers_NY_Digital_Audio',
#  'VK Community moderation_26121211',
#  'VK Community moderation_26121111',
#  'VK Community moderation_26121151',
#  'VK Community moderation_26121671',
#  'VK Community moderation_26121681',
#  'VK Community moderation_26121621',
#  'VK Community moderation_26121631',
#  'Skittles - copy Doors2',
#  'Five_Gaming_Music_Prod',
#  "CE_TMA_MM's_ScreenTime_12122019",
#  'Buttons Factory Tour 15 sec Beru, Ozon',
#  'Ice-cream KV fridges 2019 E. Stetsun',
#  'Five_Gaming_OLV_Production',
#  'TWIX Website update',
#  'Metro chrisper degustation 19-21.12.2019',
#  "CE_TMA_MM's_NY_13122019",
#  'Personal Care BBDO - 348 989,48',
#  'Orbit Mega 2020 creative\\management',
#  'Orbit Dating 2.0 KV',
#  'M&M`s Easter media formats AC',
#  'M&M`s Football TVC EBA adaptation',
#  "(7) M&M's Screentime TVC VO&tag",
#  "24_CE_MM's_Screentime TVC adaptation Del",
#  '39_CE_M&Ms_Trailer adaptation',
#  'Twix Salted Caramel Digital activation',
#  '35_M&Ms_Cupboard adaptation',
#  'BE-KIND sampling activity Dec 2019',
#  'Cashback promo Dec',
#  'Skittles Venom BTL 2019',
#  "33_MM's NY banners production",
#  'Recognition Box for Gum CBU',
#  'Perekrestok online NY - MW',
#  "Perekrestok online NY - M&M's",
#  'Perekrestok online NY - Korkunov',
#  "Film for M&M's ST selling kit",
#  'M&M`s Football Custmization AC',
#  'MMs_ivi_Content Rolls campaign_2020_3',
#  'JF OLV production',
#  'Selling kits_Twix Salted Caramel 2020',
#  'Orbit VideoCV digital assets BBDO',
#  '64_SNK Students WINTER_actors buy out',
#  'дополнение к РО 2009471551',
#  'Twix Top_Digital Support_12/2019',
#  'M&M`s NY 2020-2021 digital media formats',
#  'M&M`s Football EBA AC',
#  'Collaboration with bloggers in Tik Tok',
#  'BBDO big activation 5ka Orbit\\Snickers-2',
#  'Twix Top music buy-out',
#  'BTL_SNK Students VK check-back P12 2019',
#  'JF creative for media formats OLV+static',
#  'Juicy Fruit supervision production',
#  'Spring 2020 multibrand',
#  'Juicy Fruit Media support in Tik Tok',
#  'SNK New Year // Mix Minis Re-design',
#  'BE-KIND SMM Nov-Dec 2019',
#  'SNK EBA customized for Tander_2020',
#  'addPO2009519565_SNK EBA custom Tander 20',
#  'Orbit Mega banners design',
#  'BE-KIND WKD influencer',
#  'Rosa Fest BTL activation',
#  'M&M`s Screentime EBA AC',
#  'SNKCrisper_stickeringServiceForD-com19',
#  "32_CE_MM's CE Faint 2.0 60,20 sec Titlin",
#  'Five_Gaming_KV',
#  'Billa booking program 2019',
#  'JF media support',
#  'Five_Gaming_Web_Production',
#  'SNK OTHER // Pencil',
#  'JF production of TVC',
#  'SNK big bar deisgn // Celebrity gift',
#  '67_SNK EBA_Landing page design developem',
#  '40_CE_M&Ms_Screentime Sponsorship_Music',
#  '36_M&Ms_Screentime sponsoship adaptation',
#  "37_M&M's_Trailer VO buyouts",
#  '69_SNK Students WINTER_music buyout',
#  'Five_Gaming_Media Prod',
#  'Tander Voblers Spring Mutlibrand',
#  "CE_TMA_M&M's_Skittles_Football_12122019",
#  'MMs retainer 2020_13.12',
#  'MMs retainer 2020_14.01',
#  'TWIX Factory Tour OLV update',
#  'Twix EBA 2020 Design Development',
#  "M&M's Tablet motivation prizes 2019",
#  "M&M's Tablet motiv merch+final 2019",
#  'BE-KIND Foodservice forum activation',
#  'SNK other // Vending designs',
#  "TMA_MM's_Krispy_Kreme Branding",
#  "TMA_MM's_Krispy_Kreme+Production_1212201",
#  'Snickers_Students_1219_Plan-Digital',
#  'JF media materials development',
#  'BE-KIND cashback activation Nov',
#  'Orbit Stikers for RTS',
#  "TWIX Top OLV 20'' Materials Upload",
#  'BTL_SNKCoverForCelebs_SNKEBA2020',
#  'Decode JF copy',
#  'SNK EBA 2020 // Ivleeva rights for TV',
#  'Ice-cream KV fridges 2019 Unite',
#  '65_SNK Students WINTER_music buyout',
#  'SNK EBA // product for Dzyuba',
#  'SNK EBA 2020 // TVC prod. ball-park',
#  'BE-KIND sampling booking sept-dec Lenta',
#  'Витрина ККВ Ашан Тверская',
#  'Juicy Fruit- Media placement in colleges',
#  'BE-KIND Cashback activation/ Oct-Nov',
#  'Premium BiteSize design adaptation',
#  'BTL_SNK EBA P3-4 2020_1st part 2019',
#  'Orbit VK SP BPI Video CV',
#  'SNK H&C // concepts',
#  'Метро Офис Коркунов 20.12.2019',
#  'BE-KIND sampling oct-dec 2019',
#  'MMs Tablet motiv winner 2019',
#  'Set of redirect for domain(to promo site',
#  'Twix Salted Caramel TVC Adaptation',
#  "31_CE_M&M's Customization for Magnit 5k",
#  'Twix NY Host&Celebrate',
#  "RU_MM's_New Year_1219_Plan-Digital_06.11",
#  'Juicy Fruit BPI chashback with edadil',
#  'Korkunov Web analytics',
#  'M&Ms Tablets Catalogue in Tander',
#  '60_SNK Students WINTER_Agency Cost',
#  'дополнение к РО 2009469293',
#  'Orbit Kinetik Cashback Edadil Nov-Dec',
#  'Additional PO for Edadil Cashback',
#  'Twixit размещение в пабликах',
#  'BE-KIND business cards & POSM production',
#  'Consumer promo_Nikolaevsky_Ulan-Ude',
#  'JF creation of storyboard for test',
#  'Metro degustation KKV 22-23.11.2019',
#  'Дополнительно к РО 2009102619',
#  'BE-KIND creatives for Brandlink & OZON',
#  "31_MM's NY campaign digital support agen",
#  'Gum Macrochoice for RTS',
#  'extension to GUM video for RTS',
#  'SNK Renovate the Core // images for test',
#  'Consumer Promo_Titan Chain_UlanUde_East',
#  'Dozayvka_2009422726_Consumer promo Titan',
#  "M&M'S NY 19-20 Premia delivery",
#  'Video m&m`s and friends spring cube 2020',
#  'Orbit BPI Video CV vignette ballpark',
#  '59_SNK Gaming Producers',
#  'JF creatives for posters in colleges',
#  'BE-KIND sampling Q3',
#  "Regions Bahetle promo-M&M's",
#  'Regions Bahetle promo - MRS',
#  'Regions Bahetle promo - SNK',
#  'Regions Bahetle promo - TWX',
#  'Regions Bahetle promo - MW',
#  'Regions Bahetle promo - BNT',
#  'Regions Bahetle promo - DOVE',
#  'Kinolenta activation_Lenta',
#  'Orbit Mega Bubblemint selling kit',
#  'SNK Hungerithm // Agency cost digital',
#  'Cinema_reels_Mars_Cinema_Star_2020_(23_0',
#  'BE-KIND * Reebok digital activation',
#  'дополнение к PO 2009291148',
#  'CHOCO Web analytics',
#  "TMA_MM's_M&M's Bowl NNovgorod",
#  'BE-KIND mailing OZON',
#  "Twix TOP OLV 20'' adaptation + Tag 5",
#  'NY Voblers For tander',
#  'Twix NY Orange 2020-21_stickers for samp',
#  '63_SNK Students WINTER_OLV Adaptation',
#  'SNK New Year // Santa image buy-out',
#  'Five NY BPI`20 packaging photo buyout',
#  "29_MM's Subtitles for videos for interna",
#  'BE-KIND VK nutrition project',
#  'SNK New Year // Key visual',
#  'Ecom shooting Spring Dove',
#  'Macrochoice Gum video BBDO',
#  'Five BPI`20 Gaming 3D modeling',
#  'Five BPI`20 Gaming 3D modeling ext',
#  'RTS KKV costumes',
#  'ролик для RTS 27.09.2019 Snickers',
#  'Orbit Dating 2.0 packs design',
#  'GUM Web analytics',
#  'Milky Way NY gift packaging design',
#  'HB TVC production reconciliation',
#  'BE-KIND World Kindness Day activation',
#  'цвет настроения импульс ролик доп. Twix',
#  'Stickers for RTS_Twix SaltedCaramel2020',
#  "M&M's Frinds image buyout",
#  'импульс ролик 27.09.2019 Twix',
#  'JF BUBBLES 2020',
#  'Ролик для RTS доп.кост часть Snickers',
#  "SNK EBA'20 // Dzyuba photo-shooting",
#  "Five BPI'19 Masthead",
#  'Five AGM post-PR',
#  "Five BPI'19 Music",
#  'SNK HB // Consumer emails designs',
#  'TV SP_MMs_FridaySTS_2019_to_sent 04 10 1',
#  '14_Twix HB banners production',
#  "SNK EBA'20 // #58 KV & POSM",
#  'Orbit DAting Rambler spec.project',
#  'SKT Smoothies Samples addition',
#  'Choco logo design development for Metro',
#  'SNK OTHER // Football Effie case video',
#  'BBDO Dating promo digital material',
#  'Orbit Dating in KiB',
#  "Five BPI'19 5 advent - digital",
#  'A-brand Premia items for Orbit Dating',
#  'Five BPI digital audio',
#  'BBDO Orbit FIFA Effie case',
#  'SNK HB // Music for TVC',
#  'SNK HB // Digital media',
#  "M&M's pack icons_image buyouts",
#  'HB social amplification_production',
#  'SNK HB // CG fine-tuning',
#  "Signal samples for prizes M&M's You&Me",
#  "M&M's social Mar-Apr",
#  'Выкладка Snickers в офисе',
#  'SNK HungBar 2019_Inner BTL engagement',
#  'Ru_Plan_Digital_Orbit_Promo_BPI',
#  '5Gum.ru DataLine Hosting Q1_2019',
#  'Additional Cost - Five AFP',
#  'Additional Hoodies for Bitesize',
#  'Orbit Dating Rambler Tech cost',
#  'Orbit Mega campaign image rights',
#  'CE_Taxi buyouts',
#  'A-brands premia NCP SNK HB 2019_Choco',
#  'WrigleyMigrat:MarsPassionFootball2018_X5',
#  'SNK Crisper design vertical for POSM',
#  'BTL NCP Snickers HB+LE+BB 2019_Choco',
#  'snickers.ru DataLine Hosting Q1_2019',
#  'Five Magnit media',
#  "Five BPI'19 Banners production",
#  'Orbit BPI Dating SEM',
#  'Wrigley press trip to the factory',
#  "Orbit BPI Dating copy 15'&6' Nogmov",
#  "Five BPI'19 Magnit production",
#  'Snickers Storage of prizes',
#  "M&M's_Social_Uplift_Feb-Mar",
#  'Design production',
#  'Orbit Mega Digital support VK mask',
#  'Five LE 19/20 pack designs',
#  'BPI19 Landing Page Design Development',
#  'Orbit BPI Dating YT Masthead',
#  'SKT MEGAPOUCH Sours',
#  'Selling Kit',
#  'Orbit Dating OOH Facade Arbat 2',
#  'Regions Bahetle promo',
#  'Orbit Mega (Big Teeth) OLV, formats',
#  'Dixy Orbit Dating_additional activity',
#  'Orbit Social uplift placement',
#  'Orbit Mega KV (big teeth) development',
#  "Five BPI'19 digi",
#  'Orbit Mega digital placement',
#  'Orbit BPI Dating KV revision, add cost',
#  'Orbit Dating Dixy customized_POSM design',
#  "Boxes for sales toolkit M&M's You&Me",
#  'Orbit Dating Dixy customized',
#  'design options for sweatshots for Bitesi',
#  'Orbit Digital Social Uplift placement',
#  'SNK MS // vk test',
#  'SNK HB // Web-site',
#  'BBDO, Media formats prod.for Social upl.',
#  'BBDO, DATING Website design development',
#  'Skittles Smoothies Samples',
#  'Ozon stories images buyout',
#  'Five D-com Media Q4',
#  'KKV Attractive Frame for Globus',
#  '40_SNK_30Y_Test emoji bangbang_productio',
#  'MMs ivi New Year',
#  'SNK 30Y // Key visual',
#  'add to PO 2010204160 // KV production',
#  'NY Cashback KKV',
#  'SNK_NY 2020_Digital_Plan',
#  'Orbit Universities poster new timing',
#  'NY 2020 customizations in D-Com',
#  'Image buyout NY 20-21 digital formats',
#  'KKV_BBDO_NY 21 TVC addition_18 200',
#  'Korkunov_DigitalAmplification_Restage',
#  'SNK White // Stasprostoklass integration',
#  'add to PO 2010435074 // MediaCom FTE',
#  'SNK Anniversary 1// Pack designs (CE#35)',
#  'Korkunov_SMM_September_Digitas',
#  '46_CE_Snickers NY 2020_Galich',
#  'CP part Digital Dashboard',
#  "Creative dev-t of AR game for M&M's&Fr",
#  'Mediacom TV nov-dec 2020',
#  'SNK White // Bloggers integration',
#  'Loose visuals',
#  'Orbit Mega for case',
#  '47_CE_Snickers NY 2020_Shcherbakov',
#  'Korkunov_SMM_July_Digitas',
#  'MMs STS Jan 2021 Sponsporship',
#  'SNK Nut butter // Samples co-packing',
#  'KKV_BBDO_NY TVC update_38 200',
#  "M&M's Cupboard adaptation VO",
#  "M&M's Halloween resize d-com",
#  'BBDO NY copy tag production',
#  'Media support Twix_Hot Beverage_EBA',
#  '37_SNK_30Y_Test emoji propravda_producti',
#  'KKV_Mediacom_DC11_8 444, 38',
#  'Football promo pack Skittles',
#  'Orbit Mask media support in SN',
#  'NY Project app development',
#  'KKV_BBDO_Spring for Magnit_phrases_219k',
#  'X5 customization Buzova post',
#  'BBDO NY voiceover',
#  'KKV_BBDO_NY digital addit_23 398',
#  'Portfolio NY Treat Town in VK 2020_TMA',
#  'Twix_HB_packshot_production',
#  'BBDO Football KV buyout',
#  'Korkunov_Spring_2021',
#  'KKV_BBDO_NY digital prod_435 045',
#  'D-comm support Skittles',
#  'Five D-com_December',
#  'D-comm Strategy 2k21_OKF',
#  'BE-KIND sampling',
#  'Orbit Zoom backgrounds',
#  '63_SNK_NY_Music_Digital',
#  '62_SNK_NY_Music_TV',
#  'BE-KIND indirect sampling',
#  'Five Shmot adaptation_add',
#  'Workshop training online_26121211',
#  'Workshop training online_26121111',
#  'Workshop training online_26121151',
#  'Workshop training online_26121671',
#  'Workshop training online_26121681',
#  'Workshop training online_26121621',
#  'Workshop training online_26121631',
#  'Korkunov_SMM_November',
#  'D-Comm_MediaSupport_Korkunov_Q1',
#  'CE_M&M`s_Cupboard 20sec TR Render',
#  'KKV_Mediacom_NY21 digital_16 449 915',
#  'Orbit Refreshers website design',
#  'Workshop Training Online_OKF',
#  'Twix 3 ingredients Creative Cost',
#  'Дополнение к РО 2010458522',
#  'Juicy Fruit BPI - buyout of images',
#  '02_CE_MMs_Image for NY 20-21 packs buyou',
#  'Orbit Apricot Listing Samples',
#  '01_CE_MMs_Image for St. Valentines day K',
#  "12_MM's St. Valentines day digital forma",
#  'SNK Nut Butter // artwork add work',
#  'JF- extra cost for OLV production',
#  'KKV bags light POSm',
#  'Juicy Fruit -photo buyout for creatives',
#  'SNK Nut Butter // TMA cancellation fee',
#  'SNK EBA 2020 // Celebrity photo shooting',
#  "M&M's NY recipes",
#  'KKV national digital promo',
#  'Orbit Mask banners resize',
#  'Five NGM C1_ballpark (media assets etc)',
#  'Twix HotBev Wifi Web Development',
#  'SNK Hungerithm // Music buy-out',
#  'BE-KIND nutrition preso design',
#  'Orbit Mega R&W 16.09.2019',
#  '54_SNK_NY 2020_Photoshoot, Digital',
#  '15_Twix HB images (prizes) buy out',
#  'Orbit Edadeal Black Friday Nov 2020',
#  'Five cashback test with Brandlink',
#  'Brandlink cashback Five PO extension',
#  'Orbit Mega sampling with Beeline Feb',
#  'Visuals for NY app',
#  'SNK Hungerithm // Images buy-out',
#  'Snickers Hungeritm Tander event KRND',
#  'ORBIT OLV adaptation',
#  'Juicy Fruit Workshop',
#  'SNK EBA // Music buy-out',
#  'Digital_Twix_Hot_Beverage_Sep-Nov_2019',
#  'SNKhungeritm Tander Event Moscow office',
#  'KKV Edadeal Jan 2020',
#  'KKV Edadeal Spring 2020',
#  '26_Images for Advent Calender buyouts',
#  'Five_OLV_add cost',
#  'Twix salt creative delivery',
#  'Celebrations box for MT',
#  'Съемка полки',
#  'Skittles D-com Digitl Plan',
#  'Easter M&Ms Customisation',
#  'Easter 2020 additional for promo-site',
#  'Five Gaming EBA 2020',
#  'PO extension Five Gaming 2020',
#  'Five NGM C1 OLV_add_footage+packshot',
#  'Orbit Mega Weborama- add.VK impressions',
#  'SNK 2nd wave BBP // KV update',
#  'Five_Kanobu_special project Shmot',
#  'Media Plan D-com opportunities',
#  'BTL_Twix HB EBA P11 2020',
#  'add to PO2009921093_BTL Twix HB2020Whts',
#  'BE-KIND digital activation with goods.ru',
#  'SNICKERS creatives-global adaptation',
#  '6.328.960 - BBDO, Orbit, April',
#  'Choco_Brand Activations_D-com',
#  'Twix Seasons without Korkunov_D-com',
#  'Orbit D-com support additional',
#  "M&M's NY + Y&M Premia logistics",
#  'BE-KIND shoko stickers production',
#  'BBDO-creative fee',
#  'Media Transformation 2k21_26121211',
#  'Media Transformation 2k21_26121111',
#  'Media Transformation 2k21_26121151',
#  'Media Transformation 2k21_26121671',
#  'Media Transformation 2k21_26121681',
#  'Media Transformation 2k21_26121621',
#  'Media Transformation 2k21_26121631',
#  'Media Transformation 2k21_OKF',
#  'Five AGM T-Shirt production',
#  'BE-KIND Arena of Heroes KIND acts',
#  'Twix HotBev Digital Event Premia 19',
#  'addPO2009010160_TwixHotBev Premia 2019',
#  'SNK Hunger bar photo bay-out',
#  'Skittles Spider promo in cinema 2019',
#  "17_CE_M&M's football KV for Magnit custo",
#  "CE_MM's_Screentime_OLVs adaptation&VO",
#  'Orbit Dating 2.0 posts for SN',
#  'BBDO SOW (April) Twix',
#  'D-com materials production BBDO (covid19',
#  'Impulse activation_Lenta',
#  'SNK BBDO // April creative work',
#  'BE-KIND stickers production',
#  'SNK WHITE // Design adaptation',
#  'Orbit mask OLV for YT legal',
#  'Five NGM C1_tasks',
#  'MW Design Adaptation for STU',
#  'Twix_SaltedCaramel_digital video&TVC ad',
#  'Five_photos buyout',
#  'Five Gaming commentators',
#  'Skittles compet review',
#  "40_CE_M&M's_Images buyouts for NY egg ri",
#  'SNK EBA 2020 // promo-posts Agency cost',
#  'skittles d-com support plan',
#  'Orbit NCP 2020 PO extension',
#  "1 M&M's Screentime_masters upload",
#  'Milky Way Strawberry pack update',
#  'Twix HB EBA Pack 2020_additional cost',
#  'SNK EBA 21 // Animojis',
#  'Orbit Mango listing Samples',
#  'SNK EBA 2020 // #49 promo pack designs',
#  'Korkunov_Video_Restage_InternalLaunch',
#  'B2S 2020 Sbermarket',
#  "Orbit BPI'20 Stress // CE for KV",
#  'KKV Launch kit (2nd part)',
#  'Billa booking program',
#  'BE-KIND movie codes for 3 bars (D-com)',
#  "M&M's tube photoshoot",
#  'Korkunov_Web-SiteUpdate_Convergent',
#  'Orbit Dating contest organization',
#  'Korkunov_Zakaz_Video_Production',
#  'KKV_WebsiteUpdate_Stage2',
#  'Korkunov_Gif_BBDO',
#  'BE-KIND branding for 5LB store',
#  'Korkunov_Websitesuport_till11Jan',
#  "MM's Halloween TMA",
#  'Orbit Dating 2020 VK checkback',
#  'Orbit Dating Checkback extension',
#  'Orbit Dating 2020 PO Extension 2',
#  'NY 20-21 Screentime 3 Digital',
#  'BE-KIND POSM production for 5ka',
#  'Korkunov_HTMLBanners_TD',
#  'Launch kits KKV re-stage',
#  'Orbit Dating Media plan IG+FB',
#  'Orbit coffee banner',
#  'Orbit D-com resize',
#  'Twix EBA HB 2020_inner event',
#  'SNK NY LE // #46 Pine nut pack design',
#  'Korkunov_ProductDecr_D-Comm',
#  'SNK Almond // Pack design amendments',
#  'Orit Dating Sposorship 2020',
#  'Orbit dating 2.0 poems development',
#  'Consumer promo_Remi_6/04-10/05_5/1',
#  "37_CE_M&M's Magnit Category branding",
#  'Twix HotBev Inner Digital Engagement 19',
#  'SNK Nut Butter Selling Kits',
#  'SNK NY Canister design dev-t',
#  'Milky Way NY gift packaging design 2SKU',
#  'Orbit DAting OLV ballpark',
#  'Twix EBA 2021 pack design',
#  'BE-KIND brand ambassadors P10-P13',
#  'Spring_Photoshoot',
#  'Korkunov_ImageBuyout_TD&NY_KV',
#  'Package for MT parcel',
#  'Korkunov_SMM_October_Digitas',
#  'Orbit Universities new posters',
#  'Orbit Dating 2020 Media plan',
#  "38_CE_M&M's_Images buyouts for NY Tablet",
#  'SNK Almond // samples foil',
#  'Twix HB 2020 banners production',
#  'BE-KIND banners for D-com aug-sept',
#  'SNK NY // Agency cost for video product',
#  'Orbit D-com media placement Q4',
#  'SNK NY LE // #47 Pop corn pack design',
#  'SNK Cricper // Case study voice-over',
#  'Skittles D-com Q4',
#  'SNK EBA 2020 // Celebrities fee on-pack',
#  'add work 2009291148',
#  'SNK NY // KV photoshoot',
#  'SNK_2020_NY_ Media_Vending',
#  'Twix Orange_design development',
#  'SNK Hungerithm // #45 Banners re-size',
#  'SNK White Beyond VNP Blogger integration',
#  'Dashboard upgrades',
#  "Stock images buyout for M&M's NY Bell",
#  'SNK NY bag // pack design update',
#  'Competitive Monitoring 10 brands upg',
#  'BE-KIND media campaign digital Sept-Oct',
#  "M&M's New Year activation",
#  'BE-KIND creatives development 2',
#  'Korkunov_NY22_PackConcept_Soldis',
#  'Snickers cash-back Brandlink_oct 2020',
#  'Korkunov_Dcomm_Q4_Mediasupport',
#  'BE-KIND brochure for Shokoladnitsa',
#  'Korkunov_NY_PackCOncept_SKU2',
#  "TMA_MM's_interrogation",
#  'Five LE NY packaging photo buyout',
#  'SNK Hungerithm // OLV production',
#  "TMA_MM's_KinoExpo",
#  "TMA_MM's_KinoExpo_060919",
#  'BE-KIND performance campaign OZON',
#  'SNK Hungerithm // OLV adaptation',
#  'Icons for multipack',
#  ...]

# %%
df_ag3 = sku_standardize(list1,list2)

# %%
df_ag3
# Out:
#                         Name                                   Options  \
# 0   Back-2-School Multibrand                    Spring 2020 multibrand
# 1   Back-2-School Multibrand      NY 19-20 Tander Multibrand mechanics
# 2   Back-2-School Multibrand  NY 19-20 Multibrand in Tander (KKV part)
# 3              Big Bar promo      SNK big bar deisgn // Celebrity gift
# 4              Big Bar promo                Orbit Dating OLV promo tag
# ..                       ...                                       ...
# 82       Twix Salted Caramel          TWIX salted caramel digital plan
# 83       Twix Salted Caramel        Twix Salted Caramel TVC Adaptation
# 84                Twix White      Twix White & Top KV for internal use
# 85                Twix White                       TWIX Website update
# 86                Twix White                        TWIX Top reedit_VO
#
#         Score  Rank
# 0   55.369408     1
# 1   53.144444     2
# 2   50.553801     3
# 3   56.137270     1
# 4   55.636752     2
# ..        ...   ...
# 82  88.645833     2
# 83  87.529412     3
# 84  76.543860     1
# 85  74.208577     2
# 86  67.398148     3
#
# [87 rows x 4 columns]
